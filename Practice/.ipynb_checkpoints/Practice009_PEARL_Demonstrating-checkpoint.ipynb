# %%
import pygame, sys, random
import numpy as np
import math
import matplotlib.pyplot as plt
import pylab
from fractions import Fraction

dem_episodes = 250

obstacleRadius = 10
agentRadius = 10
goalRadius = 10

# get size of state and action from environment

dispSize = [1280, 960]
initPosAgentStandard = [dispSize[0] - 100, 500]#dispSize[1]]
initPosAgent = initPosAgentStandard#[boundaryPos[0] + boundaryLength[0] / 2, boundaryPos[1] + boundaryLength[1] / 2]
initPosGoal = [100, 500]

moveObstacles = True
action_size = 8
obsNumber = 200

# %%
def stateGenerator(intenPref, distPref):
    returnSum = [intenPref, distPref]
    returnSum = np.reshape(returnSum, [1, state_size])
#     print returnSum
    return returnSum

# %%
def takeAction(action):
    xAction = 0
    yAction = 0
    actionOffset = 1
    if action == 0:
        xAction = actionOffset
    elif action == 1:
        xAction = actionOffset
        yAction = actionOffset
    elif action == 2:
        xAction = actionOffset
        yAction = -actionOffset
    elif action == 3:
        xAction = -actionOffset
        yAction = actionOffset
    elif action == 4:
        xAction = -actionOffset
    elif action == 5:
        xAction = -actionOffset
        yAction = -actionOffset
    elif action == 6:
        yAction = -actionOffset
    elif action == 7:
        yAction = actionOffset
    elif action == 8:
        xAction = 0
        yAction = 0
        
    return [xAction, yAction]

# %%
def makeFeature(agtPos, goalPos, obsPos, const):
    feature1 = (agtPos[0] - goalPos[0])**2 + (agtPos[1] - goalPos[1])**2
    feature2 = 1 / ((agtPos[0] - obsPos[0])**2 + (agtPos[1] - obsPos[1])**2 + const)
    return [feature1, feature2]

# %%
def rangeFinder(allObsPos, rangeCenter):
    allObsAgtDistance = [0 for _ in range(obsNumber)]
    for i in range(0, obsNumber):
        allObsAgtDistance[i] = math.sqrt((allObsPos[i][0] - rangeCenter[0])**2 + (allObsPos[i][1] - rangeCenter[1])**2)
    index = np.argmin(allObsAgtDistance)
    return index

# %%
pygame.init()

screen = pygame.display.set_mode(dispSize)
screen.fill([200, 200, 200])

rList, episodes = [], []
yOffset = 100
xOffset = 50
# weightVec = [-0.23, -0.1696] # PEARL Parameter
# weightVec = [-0.85232079, -0.8940559] #Trained Parameter from [90, 90]
weightVec = [-0.08357393, -0.6748898]
# weightVec = [-0.88452816, -0.64293331]
# weightVec = [-0.00157787, -0.75601858]
# Make Obstacles (obsNumber)
obstaclePos = [[0, 0] for _ in range(obsNumber)]
# for i in range(0,obsNumber):
#     obstaclePos[i][0] = int(150 + i % 15 * 100)
#     obstaclePos[i][1] = int(yOffset + i / 15 * 100)
for i in range(0,obsNumber):
    obstaclePos[i][0] = int(150 + i % 14 * 80)
    obstaclePos[i][1] = int(80 + i / 14 * 80)

Qs = [0 for _ in range(action_size)]
for e in range(dem_episodes):
    # Initialize
    done = False
    score = 0
    x = initPosAgent[0]
    y = initPosAgent[1]
    print("Episode ", e, "Starts!")
    xMove = 0
    yMove = 0
    while not done:

        for i in range(0,action_size):
            [tmpXMove, tmpYMove] = takeAction(i)
            tmpX = x + tmpXMove
            tmpY = y + tmpYMove
            idx = rangeFinder(obstaclePos, [tmpX,tmpY])
            FeatureVec1 = (tmpX - initPosGoal[0])**2 + (tmpY - initPosGoal[1])**2
            FeatureVec2 = 100000.0 / (0.0 + (tmpX - obstaclePos[idx][0])**2 + (tmpY - obstaclePos[idx][1])**2)
            Qs[i] = weightVec[0] * FeatureVec1 + weightVec[1] * FeatureVec2
#         print Qs
        action = np.argmax(Qs)
#         print action, '\r',
        [xMove, yMove] = takeAction(action)

        x = x + xMove
        y = y + yMove

        wallFlag = 0
        collisionFlag = 0
        pygame.draw.circle(screen, [100, 100, 255], [x,y], agentRadius, 0)

        initPosAgent = [x,y]

        if math.sqrt((x -  initPosGoal[0])**2 + (y - initPosGoal[1])**2) <= agentRadius:
            print("Goal Reached!")
            collisionFlag = 1
            done = True
            rList.append(1)
        for i in range(0,obsNumber):
            obstaclePos[i][0] = obstaclePos[i][0] + random.randrange(-1,2)
            obstaclePos[i][1] = obstaclePos[i][1] + random.randrange(-1,2)
            if i == idx:
                pygame.draw.circle(screen, [255, 255, 50], obstaclePos[i], obstacleRadius, 0)
            else:
                pygame.draw.circle(screen, [255, 50, 50], obstaclePos[i], obstacleRadius, 0)
            if math.sqrt((x - obstaclePos[i][0])**2 + (y - obstaclePos[i][1])**2) < 19:
                print("Collision!")
                collisionFlag = -1
                done = True
                rList.append(0)

        if done:
            # every episode, plot the play time
            initPosAgent = initPosAgentStandard
            obstaclePos = [[0, 0] for _ in range(obsNumber)]
#             for i in range(0,obsNumber):
#                 obstaclePos[i][0] = int(150 + i % 15 * 100)
#                 obstaclePos[i][1] = int(yOffset + i / 15 * 100)
            for i in range(0,obsNumber):
                obstaclePos[i][0] = int(150 + i % 14 * 80)
                obstaclePos[i][1] = int(80 + i / 14 * 80)
            episodes.append(e)

        pygame.draw.circle(screen, [100,255,100], initPosGoal, 10, 2)
        pygame.display.flip()
        screen.fill([220,220,220])
    print("Percent of successful episodes: " + str(100.0 * sum(rList)/(e + 1)) + "%")
# Out:
# ('Episode ', 0, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 100.0%
# ('Episode ', 1, 'Starts!')
# Collision!
# Percent of successful episodes: 50.0%
# ('Episode ', 2, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 66.6666666667%
# ('Episode ', 3, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.0%
# ('Episode ', 4, 'Starts!')
# Collision!
# Percent of successful episodes: 60.0%
# ('Episode ', 5, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 66.6666666667%
# ('Episode ', 6, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.4285714286%
# ('Episode ', 7, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.0%
# ('Episode ', 8, 'Starts!')
# Collision!
# Percent of successful episodes: 66.6666666667%
# ('Episode ', 9, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.0%
# ('Episode ', 10, 'Starts!')
# Collision!
# Percent of successful episodes: 63.6363636364%
# ('Episode ', 11, 'Starts!')
# Collision!
# Percent of successful episodes: 58.3333333333%
# ('Episode ', 12, 'Starts!')
# Collision!
# Percent of successful episodes: 53.8461538462%
# ('Episode ', 13, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 57.1428571429%
# ('Episode ', 14, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 60.0%
# ('Episode ', 15, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 62.5%
# ('Episode ', 16, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 64.7058823529%
# ('Episode ', 17, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 66.6666666667%
# ('Episode ', 18, 'Starts!')
# Collision!
# Percent of successful episodes: 63.1578947368%
# ('Episode ', 19, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 65.0%
# ('Episode ', 20, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 66.6666666667%
# ('Episode ', 21, 'Starts!')
# Collision!
# Percent of successful episodes: 63.6363636364%
# ('Episode ', 22, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 65.2173913043%
# ('Episode ', 23, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 66.6666666667%
# ('Episode ', 24, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 68.0%
# ('Episode ', 25, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 69.2307692308%
# ('Episode ', 26, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.3703703704%
# ('Episode ', 27, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.4285714286%
# ('Episode ', 28, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 72.4137931034%
# ('Episode ', 29, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.3333333333%
# ('Episode ', 30, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.1935483871%
# ('Episode ', 31, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.0%
# ('Episode ', 32, 'Starts!')
# Collision!
# Collision!
# Percent of successful episodes: 72.7272727273%
# ('Episode ', 33, 'Starts!')
# Collision!
# Percent of successful episodes: 70.5882352941%
# ('Episode ', 34, 'Starts!')
# Collision!
# Percent of successful episodes: 68.5714285714%
# ('Episode ', 35, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 69.4444444444%
# ('Episode ', 36, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.2702702703%
# ('Episode ', 37, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.0526315789%
# ('Episode ', 38, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.7948717949%
# ('Episode ', 39, 'Starts!')
# Collision!
# Percent of successful episodes: 70.0%
# ('Episode ', 40, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.7317073171%
# ('Episode ', 41, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.4285714286%
# ('Episode ', 42, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 72.0930232558%
# ('Episode ', 43, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 72.7272727273%
# ('Episode ', 44, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.3333333333%
# ('Episode ', 45, 'Starts!')
# Collision!
# Percent of successful episodes: 71.7391304348%
# ('Episode ', 46, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 72.3404255319%
# ('Episode ', 47, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 72.9166666667%
# ('Episode ', 48, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.4693877551%
# ('Episode ', 49, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.0%
# ('Episode ', 50, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.5098039216%
# ('Episode ', 51, 'Starts!')
# Collision!
# Percent of successful episodes: 73.0769230769%
# ('Episode ', 52, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.5849056604%
# ('Episode ', 53, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.0740740741%
# ('Episode ', 54, 'Starts!')
# Collision!
# Percent of successful episodes: 72.7272727273%
# ('Episode ', 55, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.2142857143%
# ('Episode ', 56, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.6842105263%
# ('Episode ', 57, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.1379310345%
# ('Episode ', 58, 'Starts!')
# Collision!
# Collision!
# Percent of successful episodes: 72.8813559322%
# ('Episode ', 59, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.3333333333%
# ('Episode ', 60, 'Starts!')
# Collision!
# Collision!
# Percent of successful episodes: 72.131147541%
# ('Episode ', 61, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 72.5806451613%
# ('Episode ', 62, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.0158730159%
# ('Episode ', 63, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.4375%
# ('Episode ', 64, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.8461538462%
# ('Episode ', 65, 'Starts!')
# Collision!
# Percent of successful episodes: 72.7272727273%
# ('Episode ', 66, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.1343283582%
# ('Episode ', 67, 'Starts!')
# Collision!
# Percent of successful episodes: 72.0588235294%
# ('Episode ', 68, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 72.4637681159%
# ('Episode ', 69, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 72.8571428571%
# ('Episode ', 70, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.2394366197%
# ('Episode ', 71, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.6111111111%
# ('Episode ', 72, 'Starts!')
# Collision!
# Percent of successful episodes: 72.602739726%
# ('Episode ', 73, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 72.972972973%
# ('Episode ', 74, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.3333333333%
# ('Episode ', 75, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.6842105263%
# ('Episode ', 76, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.025974026%
# ('Episode ', 77, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.358974359%
# ('Episode ', 78, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.6835443038%
# ('Episode ', 79, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.0%
# ('Episode ', 80, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.3086419753%
# ('Episode ', 81, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.6097560976%
# ('Episode ', 82, 'Starts!')
# Collision!
# Percent of successful episodes: 74.6987951807%
# ('Episode ', 83, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.0%
# ('Episode ', 84, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.2941176471%
# ('Episode ', 85, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.5813953488%
# ('Episode ', 86, 'Starts!')
# Collision!
# Percent of successful episodes: 74.7126436782%
# ('Episode ', 87, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.0%
# ('Episode ', 88, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.2808988764%
# ('Episode ', 89, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.5555555556%
# ('Episode ', 90, 'Starts!')
# Collision!
# Collision!
# Percent of successful episodes: 74.7252747253%
# ('Episode ', 91, 'Starts!')
# Collision!
# Percent of successful episodes: 73.9130434783%
# ('Episode ', 92, 'Starts!')
# Collision!
# Percent of successful episodes: 73.1182795699%
# ('Episode ', 93, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.4042553191%
# ('Episode ', 94, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.6842105263%
# ('Episode ', 95, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.9583333333%
# ('Episode ', 96, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.2268041237%
# ('Episode ', 97, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.4897959184%
# ('Episode ', 98, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.7474747475%
# ('Episode ', 99, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.0%
# ('Episode ', 100, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.2475247525%
# ('Episode ', 101, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.4901960784%
# ('Episode ', 102, 'Starts!')
# Collision!
# Percent of successful episodes: 74.7572815534%
# ('Episode ', 103, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.0%
# ('Episode ', 104, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.2380952381%
# ('Episode ', 105, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.4716981132%
# ('Episode ', 106, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.7009345794%
# ('Episode ', 107, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.9259259259%
# ('Episode ', 108, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 76.1467889908%
# ('Episode ', 109, 'Starts!')
# Collision!
# Percent of successful episodes: 75.4545454545%
# ('Episode ', 110, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.6756756757%
# ('Episode ', 111, 'Starts!')
# Collision!
# Percent of successful episodes: 75.0%
# ('Episode ', 112, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.2212389381%
# ('Episode ', 113, 'Starts!')
# Collision!
# Percent of successful episodes: 74.5614035088%
# ('Episode ', 114, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.7826086957%
# ('Episode ', 115, 'Starts!')
# Collision!
# Percent of successful episodes: 74.1379310345%
# ('Episode ', 116, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.358974359%
# ('Episode ', 117, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.5762711864%
# ('Episode ', 118, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.7899159664%
# ('Episode ', 119, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 75.0%
# ('Episode ', 120, 'Starts!')
# Collision!
# Percent of successful episodes: 74.3801652893%
# ('Episode ', 121, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.5901639344%
# ('Episode ', 122, 'Starts!')
# Collision!
# Percent of successful episodes: 73.9837398374%
# ('Episode ', 123, 'Starts!')
# Collision!
# Percent of successful episodes: 73.3870967742%
# ('Episode ', 124, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.6%
# ('Episode ', 125, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.8095238095%
# ('Episode ', 126, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.0157480315%
# ('Episode ', 127, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.21875%
# ('Episode ', 128, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.4186046512%
# ('Episode ', 129, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.6153846154%
# ('Episode ', 130, 'Starts!')
# Collision!
# Percent of successful episodes: 74.0458015267%
# ('Episode ', 131, 'Starts!')
# Collision!
# Percent of successful episodes: 73.4848484848%
# ('Episode ', 132, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.6842105263%
# ('Episode ', 133, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.8805970149%
# ('Episode ', 134, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.0740740741%
# ('Episode ', 135, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.2647058824%
# ('Episode ', 136, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.4525547445%
# ('Episode ', 137, 'Starts!')
# Collision!
# Percent of successful episodes: 73.9130434783%
# ('Episode ', 138, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.1007194245%
# ('Episode ', 139, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.2857142857%
# ('Episode ', 140, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.4680851064%
# ('Episode ', 141, 'Starts!')
# Collision!
# Percent of successful episodes: 73.9436619718%
# ('Episode ', 142, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.1258741259%
# ('Episode ', 143, 'Starts!')
# Collision!
# Percent of successful episodes: 73.6111111111%
# ('Episode ', 144, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.7931034483%
# ('Episode ', 145, 'Starts!')
# Collision!
# Percent of successful episodes: 73.2876712329%
# ('Episode ', 146, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.4693877551%
# ('Episode ', 147, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.6486486486%
# ('Episode ', 148, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.8255033557%
# ('Episode ', 149, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.0%
# ('Episode ', 150, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 74.1721854305%
# ('Episode ', 151, 'Starts!')
# Collision!
# Percent of successful episodes: 73.6842105263%
# ('Episode ', 152, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.8562091503%
# ('Episode ', 153, 'Starts!')
# Collision!
# Percent of successful episodes: 73.3766233766%
# ('Episode ', 154, 'Starts!')
# Collision!
# Percent of successful episodes: 72.9032258065%
# ('Episode ', 155, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.0769230769%
# ('Episode ', 156, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.2484076433%
# ('Episode ', 157, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.417721519%
# ('Episode ', 158, 'Starts!')
# Collision!
# Percent of successful episodes: 72.9559748428%
# ('Episode ', 159, 'Starts!')
# Collision!
# Percent of successful episodes: 72.5%
# ('Episode ', 160, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 72.6708074534%
# ('Episode ', 161, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 72.8395061728%
# ('Episode ', 162, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 73.0061349693%
# ('Episode ', 163, 'Starts!')
# Collision!
# Percent of successful episodes: 72.5609756098%
# ('Episode ', 164, 'Starts!')
# Collision!
# Percent of successful episodes: 72.1212121212%
# ('Episode ', 165, 'Starts!')
# Collision!
# Percent of successful episodes: 71.686746988%
# ('Episode ', 166, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.8562874251%
# ('Episode ', 167, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 72.0238095238%
# ('Episode ', 168, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 72.1893491124%
# ('Episode ', 169, 'Starts!')
# Collision!
# Percent of successful episodes: 71.7647058824%
# ('Episode ', 170, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.9298245614%
# ('Episode ', 171, 'Starts!')
# Collision!
# Percent of successful episodes: 71.511627907%
# ('Episode ', 172, 'Starts!')
# Collision!
# Percent of successful episodes: 71.098265896%
# ('Episode ', 173, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.2643678161%
# ('Episode ', 174, 'Starts!')
# Collision!
# Percent of successful episodes: 70.8571428571%
# ('Episode ', 175, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.0227272727%
# ('Episode ', 176, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.186440678%
# ('Episode ', 177, 'Starts!')
# Collision!
# Collision!
# Percent of successful episodes: 70.7865168539%
# ('Episode ', 178, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.9497206704%
# ('Episode ', 179, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.1111111111%
# ('Episode ', 180, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.270718232%
# ('Episode ', 181, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.4285714286%
# ('Episode ', 182, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.5846994536%
# ('Episode ', 183, 'Starts!')
# Collision!
# Percent of successful episodes: 71.1956521739%
# ('Episode ', 184, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.3513513514%
# ('Episode ', 185, 'Starts!')
# Collision!
# Percent of successful episodes: 70.9677419355%
# ('Episode ', 186, 'Starts!')
# Collision!
# Percent of successful episodes: 70.5882352941%
# ('Episode ', 187, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.7446808511%
# ('Episode ', 188, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.8994708995%
# ('Episode ', 189, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.0526315789%
# ('Episode ', 190, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.2041884817%
# ('Episode ', 191, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.3541666667%
# ('Episode ', 192, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.5025906736%
# ('Episode ', 193, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.6494845361%
# ('Episode ', 194, 'Starts!')
# Collision!
# Percent of successful episodes: 71.2820512821%
# ('Episode ', 195, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.4285714286%
# ('Episode ', 196, 'Starts!')
# Collision!
# Percent of successful episodes: 71.0659898477%
# ('Episode ', 197, 'Starts!')
# Collision!
# Percent of successful episodes: 70.7070707071%
# ('Episode ', 198, 'Starts!')
# Collision!
# Percent of successful episodes: 70.351758794%
# ('Episode ', 199, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.5%
# ('Episode ', 200, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.6467661692%
# ('Episode ', 201, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.7920792079%
# ('Episode ', 202, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.9359605911%
# ('Episode ', 203, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.0784313725%
# ('Episode ', 204, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.2195121951%
# ('Episode ', 205, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.359223301%
# ('Episode ', 206, 'Starts!')
# Collision!
# Percent of successful episodes: 71.0144927536%
# ('Episode ', 207, 'Starts!')
# Collision!
# Percent of successful episodes: 70.6730769231%
# ('Episode ', 208, 'Starts!')
# Collision!
# Percent of successful episodes: 70.3349282297%
# ('Episode ', 209, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.4761904762%
# ('Episode ', 210, 'Starts!')
# Collision!
# Percent of successful episodes: 70.1421800948%
# ('Episode ', 211, 'Starts!')
# Collision!
# Percent of successful episodes: 69.8113207547%
# ('Episode ', 212, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 69.9530516432%
# ('Episode ', 213, 'Starts!')
# Collision!
# Percent of successful episodes: 69.6261682243%
# ('Episode ', 214, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 69.7674418605%
# ('Episode ', 215, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 69.9074074074%
# ('Episode ', 216, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.0460829493%
# ('Episode ', 217, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.1834862385%
# ('Episode ', 218, 'Starts!')
# Collision!
# Percent of successful episodes: 69.8630136986%
# ('Episode ', 219, 'Starts!')
# Collision!
# Percent of successful episodes: 69.5454545455%
# ('Episode ', 220, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 69.6832579186%
# ('Episode ', 221, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 69.8198198198%
# ('Episode ', 222, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 69.9551569507%
# ('Episode ', 223, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.0892857143%
# ('Episode ', 224, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.2222222222%
# ('Episode ', 225, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.3539823009%
# ('Episode ', 226, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.4845814978%
# ('Episode ', 227, 'Starts!')
# Collision!
# Percent of successful episodes: 70.1754385965%
# ('Episode ', 228, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.3056768559%
# ('Episode ', 229, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.4347826087%
# ('Episode ', 230, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.5627705628%
# ('Episode ', 231, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.6896551724%
# ('Episode ', 232, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.8154506438%
# ('Episode ', 233, 'Starts!')
# Collision!
# Percent of successful episodes: 70.5128205128%
# ('Episode ', 234, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.6382978723%
# ('Episode ', 235, 'Starts!')
# Collision!
# Percent of successful episodes: 70.3389830508%
# ('Episode ', 236, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.4641350211%
# ('Episode ', 237, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.5882352941%
# ('Episode ', 238, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.7112970711%
# ('Episode ', 239, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.8333333333%
# ('Episode ', 240, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.9543568465%
# ('Episode ', 241, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 71.0743801653%
# ('Episode ', 242, 'Starts!')
# Collision!
# Percent of successful episodes: 70.7818930041%
# ('Episode ', 243, 'Starts!')
# Collision!
# Percent of successful episodes: 70.4918032787%
# ('Episode ', 244, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.612244898%
# ('Episode ', 245, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.7317073171%
# ('Episode ', 246, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.8502024291%
# ('Episode ', 247, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.9677419355%
# ('Episode ', 248, 'Starts!')
# Collision!
# Percent of successful episodes: 70.6827309237%
# ('Episode ', 249, 'Starts!')
# Goal Reached!
# Percent of successful episodes: 70.8%

# %%
print("Percent of successful episodes: " + str(100.0 * sum(rList)/num_episodes) + "%")

# plt.bar(range(len(rList)), rList, color = "Blue", width = 0.00001)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-64363ee5cd2f> in <module>()
# ----> 1 print("Percent of successful episodes: " + str(100.0 * sum(rList)/num_episodes) + "%")
#       2
#       3 # plt.bar(range(len(rList)), rList, color = "Blue", width = 0.00001)
#       4 # plt.show()
#
# NameError: name 'num_episodes' is not defined
