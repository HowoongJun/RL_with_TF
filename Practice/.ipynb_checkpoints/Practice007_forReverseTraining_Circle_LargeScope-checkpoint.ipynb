# %%
import pygame, sys, random
import numpy as np
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import Adam
import math
import matplotlib.pyplot as plt
import pylab
from fractions import Fraction
import time

num_episodes = 1

obstacleRadius = 10
agentRadius = 10

# get size of state and action from environment

boundaryPos = [100, 100]
boundaryLength = [70,70]
boundaryRadius = 40
dispSize = [1280, 960]
initPosAgentStandard = [dispSize[0] - 100, 100]#dispSize[1]]
initPosAgent = initPosAgentStandard#[boundaryPos[0] + boundaryLength[0] / 2, boundaryPos[1] + boundaryLength[1] / 2]
goalPos = [100, 900]
goalAngle = 0#random.randrange(0, 360) * math.pi / 180

obstacleRandomRange = 1000

moveObstacles = True
action_size = 9
obsNumber = 200
state_size = 2
# state_size = obsNumber + 1
# Out:
# Using TensorFlow backend.

# %%
# A2C(Advantage Actor-Critic) agent
class A2CAgent:
    def __init__(self, state_size, action_size):
        self.load_model1 = True
        self.load_model2 = False
        
        # get size of state and action
        self.state_size = state_size
        self.action_size = action_size
        self.value_size = 1

        # These are hyper parameters for the Policy Gradient
        self.discount_factor = 0.99
        self.actor_lr = 0.00002
        self.critic_lr = 0.00005

        # create model for policy network
        self.actor = self.build_actor()
        self.critic = self.build_critic()
        self.actorMacro = self.build_actorMacro()
        self.criticMacro = self.build_criticMacro()

        if self.load_model1:
            self.actor.load_weights("./Practice004_DataSave/Actor_Rev.h5")
            self.critic.load_weights("./Practice004_DataSave/Critic_Rev.h5")
            
        if self.load_model2:
            self.actorMacro.load_weights("./Practice004_DataSave/Actor_Macro.h5")
            self.actorMacro.load_weights("./Practice004_DataSave/Critic_Macro.h5")
#             print self.actor.weights
#             print self.critic.weights
    # approximate policy and value using Neural Network
    # actor: state is input and probability of each action is output of model
    def build_actor(self):
        actor = Sequential()
        actor.add(Dense(128, input_dim=self.state_size, activation='relu', kernel_initializer='glorot_normal'))
        actor.add(Dense(self.action_size, activation='softmax', kernel_initializer='glorot_normal'))
        actor.summary()
        # See note regarding crossentropy in cartpole_reinforce.py
        actor.compile(loss='categorical_crossentropy', optimizer=Adam(lr=self.actor_lr))
        return actor

    # critic: state is input and value of state is output of model
    def build_critic(self):
        critic = Sequential()
        critic.add(Dense(128, input_dim=self.state_size, activation='relu', kernel_initializer='glorot_normal'))
        critic.add(Dense(self.value_size, activation='linear', kernel_initializer='glorot_normal'))
        critic.summary()
        critic.compile(loss="mse", optimizer=Adam(lr=self.critic_lr))
        return critic

    def build_actorMacro(self):
        actorMacro = Sequential()
        actorMacro.add(Dense(128, input_dim=self.state_size, activation='relu', kernel_initializer='glorot_normal'))
        actorMacro.add(Dense(self.action_size, activation='softmax', kernel_initializer='glorot_normal'))
        actorMacro.summary()
        # See note regarding crossentropy in cartpole_reinforce.py
        actorMacro.compile(loss='categorical_crossentropy', optimizer=Adam(lr=self.actor_lr))
        return actorMacro

    # critic: state is input and value of state is output of model
    def build_criticMacro(self):
        criticMacro = Sequential()
        criticMacro.add(Dense(128, input_dim=self.state_size, activation='relu', kernel_initializer='glorot_normal'))
        criticMacro.add(Dense(self.value_size, activation='linear', kernel_initializer='glorot_normal'))
        criticMacro.summary()
        criticMacro.compile(loss="mse", optimizer=Adam(lr=self.critic_lr))
        return criticMacro
    
    # using the output of policy network, pick action stochastically
    def get_action(self, state):
        policy = self.actor.predict(state, batch_size=1).flatten()
#         print policy
        return policy
#         return np.random.choice(self.action_size, 1, p=policy)[0]

    def get_actionMacro(self, state):
        policy = self.actor.predict(state, batch_size=1).flatten()
#         print policy
        return policy
#         return np.random.choice(self.action_size, 1, p=policy)[0]

    # update policy network every episode
    def train_model(self, state, action, reward, next_state, done):
        target = np.zeros((1, self.value_size))
        advantages = np.zeros((1, self.action_size))

        value = self.critic.predict(state)[0]
        next_value = self.critic.predict(next_state)[0]

        if done:
            advantages[0][action] = reward - value
            target[0][0] = reward
        else:
            advantages[0][action] = reward + self.discount_factor * (next_value) - value
            target[0][0] = reward + self.discount_factor * next_value

        self.actor.fit(state, advantages, epochs=1, verbose=0)
        self.critic.fit(state, target, epochs=1, verbose=0)

# %%
def stateGenerator(obsPosition, agtPosition, idx):
    returnSum = []
    if idx != -1:
        returnSum = returnSum + [agtPosition[0] - obsPosition[idx][0], agtPosition[1] - obsPosition[idx][1]]
    else:
        returnSum = returnSum + [agtPosition[0] - obsPosition[0], agtPosition[1] - obsPosition[1]]
    returnSum = np.reshape(returnSum, [1, state_size])
    return returnSum

# %%
def takeAction(action):
    xAction = 0
    yAction = 0
    if action == 0:
        xAction = 1
    elif action == 1:
        xAction = 1
        yAction = 1
    elif action == 2:
        xAction = 1
        yAction = -1            
    elif action == 3:
        xAction = -1
        yAction = 1
    elif action == 4:
        xAction = -1
    elif action == 5:
        xAction = -1
        yAction = -1
    elif action == 6:
        yAction = -1
    elif action == 7:
        yAction = 1
    elif action == 8:
        xAction = 0
        yAction = 0
        
    return [xAction, yAction]

# %%
def rangeFinder(allObsPos, rangeCenter):
    countObs = 0
    rangeObstacle = [[0,0] for _ in range(obsNumber)]
    allObsAgtDistance = [0 for _ in range(obsNumber)]
    for i in range(0, obsNumber):
        allObsAgtDistance[i] = math.sqrt((allObsPos[i][0] - rangeCenter[0])**2 + (allObsPos[i][1] - rangeCenter[1])**2)
        if math.sqrt((rangeCenter[0] - allObsPos[i][0])**2 + (rangeCenter[1] - allObsPos[i][1])**2) < boundaryRadius:
            rangeObstacle[countObs] = allObsPos[i]
            countObs += 1
    index = np.argmin(allObsAgtDistance)
    return [countObs, rangeObstacle, index]

# %%
def goalFinder(agtPos):
    if goalPos[0] == agtPos[0]:
        if goalPos[1] > agtPos[1]:
            goalAngle = 90 * math.pi / 180
        else:
            goalAngle = -90 * math.pi / 180
    else:
        goalAngle = math.atan(1.0*(goalPos[1]-agtPos[1])/(goalPos[0]-agtPos[0]))
    if goalPos[0] < agtPos[0]:
        goalAngle += math.pi
        
    tmpGoal = [0,0]
    tmpGoal[0] = int(math.floor(agtPos[0] + boundaryRadius * math.cos(goalAngle)))
    tmpGoal[1] = int(math.floor(agtPos[1] + boundaryRadius * math.sin(goalAngle)))
    return tmpGoal

# %%
def nearestAction(actionIdx):
    nearAction = []
    if actionIdx == 0:
        nearAction = [1, 2]
    elif actionIdx == 1:
        nearAction = [0, 7]
    elif actionIdx == 2:
        nearAction = [0, 6]
    elif actionIdx == 3:
        nearAction = [4, 7]
    elif actionIdx == 4:
        nearAction = [3, 5]
    elif actionIdx == 5:
        nearAction = [4, 6]
    elif actionIdx == 6:
        nearAction = [5, 2]
    elif actionIdx == 7:
        nearAction = [1, 3]
    else:
        nearAction = [8, 8]
    return nearAction

# %%
pygame.init()
screen = pygame.display.set_mode(dispSize)
screen.fill([200, 200, 200])

# make A2C agent
agent = A2CAgent(state_size, action_size)
# agentMacro = A2CAgent(state_size, action_size)
rList, episodes = [], []

# Make Obstacles (obsNumber)
obstaclePos = [[0, 0] for _ in range(obsNumber)]
for i in range(0,obsNumber):
#     obsRadius = random.randrange(agentRadius + obstacleRadius + 10, obstacleRandomRange)
#     obsAngle = random.randrange(90,180) * math.pi / 180
#     obstaclePos[i][0] = int(initPosAgent[0] + obsRadius * math.cos(obsAngle)) #boundaryPos[0] + random.randrange(1, boundaryLength[0])
#     obstaclePos[i][1] = int(initPosAgent[1] + obsRadius * math.sin(obsAngle)) #boundaryPos[1] + random.randrange(1, boundaryLength[1])
#    obstaclePos[i][0] = int(initPosAgent[0] - (obstacleRadius + agentRadius + random.randrange(0, dispSize[0])))
#    obstaclePos[i][1] = int(initPosAgent[1] + (obstacleRadius + agentRadius + random.randrange(0, dispSize[1])))
#     obstaclePos[i][0] = int(150 + i % 14 * 80)
#     obstaclePos[i][1] = int(i / 14 * 80)
    obstaclePos[i][0] = int(150 + i % 7 * 150)
    obstaclePos[i][1] = int(150 + i / 7 * 150)
for e in range(num_episodes):
    # Initialize
    start = time.time()
    frame = 0
    done = False
    score = 0
    x = initPosAgent[0]
    y = initPosAgent[1]
    print("Episode ", e, "Starts!")
    macroPolicy = []
    macroState = []
    [rangeObsNumber, rangeObsPos, minIndex] = rangeFinder(obstaclePos, initPosAgent)
    macroState = stateGenerator([obstaclePos[minIndex][0], obstaclePos[minIndex][1]], [x, y], -1)
    while not done:
#         print rangeObsNumber
#         macroPolicy = agentMacro.get_actionMacro(macroState)
#         macroPolicy = agent.get_action(macroState)
        frame += 1
        tmpAction = []
        for i in range(0,rangeObsNumber):
            state = stateGenerator(rangeObsPos, [x,y], i)
            policyArr = agent.get_action(state)
            if i == 0:
                tmpAction = (1 - policyArr)
            else:
                tmpAction = tmpAction * (1 - policyArr)
#         print("0: ", tmpAction)
        
        if tmpAction != []:
            for j in range(0, action_size):
                if tmpAction[j] > 0.9999:
                    tmpAction[j] = 1
#                 elif tmpAction[j] > 0.995:
#                     tmpAction[j] = 0.1
                else:
                    tmpAction[j] = 0
            tmpArgMax = np.argmax(tmpAction)
            
#         tmpAction = [round(elem,0) for elem in tmpAction]
            
#         if rangeObsNumber != 0:
#             tmpAction = tmpAction * (1 - macroPolicy)
#         print("1:", macroPolicy)
    
        if rangeObsNumber == 0:
            tmpAction = [1.0/action_size for _ in range(0, action_size)]
        
        tmpGoalPos = goalFinder([x, y])
        state = stateGenerator(tmpGoalPos, [x,y], -1)
        policyArr = agent.get_action(state)

        if np.mean(tmpAction) == 0:
            tmpAction[tmpArgMax] = 1
        
        tmpAction = tmpAction * np.asarray(policyArr)
    
        tmpAction = tmpAction / np.sum(tmpAction)
        action = np.random.choice(action_size, 1, p = tmpAction)[0]

        xMove = 0
        yMove = 0

        [xMove, yMove] = takeAction(action)

        x = x + xMove
        y = y + yMove

        wallFlag = 0
        collisionFlag = 0
#         [x, y] = ckWall(x, y)
        pygame.draw.circle(screen, [100, 100, 255], [x,y], 10, 0)
#         pic = pygame.image.load("image/vacumrobot.jpg")
#         pic = pygame.transform.scale(pic, (40, 40))
#         screen.blit(pic, [x - agentRadius,y - agentRadius])
#         next_state = stateGenerator(obstaclePos, [x,y])\
        [rangeObsNumber, rangeObsPos, minIndex] = rangeFinder(obstaclePos, initPosAgent)
        next_macroState = stateGenerator([obstaclePos[minIndex][0], obstaclePos[minIndex][1]], [x, y], -1)

        initPosAgent = [x,y]
   
        if math.sqrt((x -  goalPos[0])**2 + (y - goalPos[1])**2) <= agentRadius:
            print("Goal Reached!")
            collisionFlag = 1
            done = True
        for i in range(0,obsNumber):
            if moveObstacles:
                obstaclePos[i][0] = obstaclePos[i][0] + random.randrange(-1,2)
                obstaclePos[i][1] = obstaclePos[i][1] + random.randrange(-1,2)
                
            pygame.draw.circle(screen, [255, 50, 50], obstaclePos[i], obstacleRadius, 0)
            if math.sqrt((x - obstaclePos[i][0])**2 + (y - obstaclePos[i][1])**2) < 19:
                print("Collision!")
                collisionFlag = -1
                print tmpAction
                done = True
#                 break
        
        if not done:
            reward = 0

        else:
            if collisionFlag == 1:
                reward = 0
                rList.append(1)
            elif collisionFlag == -1:
                reward = 1000
                rList.append(0)
#        if rangeObsNumber != 0:
#            agent.train_model(macroState, action, reward, next_macroState, done)
#        macroState = next_macroState
    
        score += reward
#         state = next_state
#         if score >= 10000:
#             print "Success!"
#             done = True
        pygame.draw.circle(screen, [255,100,100], initPosAgent, boundaryRadius, 2)

        if done:
            # every episode, plot the play time
            initPosAgent = initPosAgentStandard
            obstaclePos = [[0, 0] for _ in range(obsNumber)]
            for i in range(0,obsNumber):
#                 obsRadius = random.randrange(agentRadius + obstacleRadius + 100, obstacleRandomRange)
#                 obsAngle = random.randrange(90,180) * math.pi / 180
#                 obstaclePos[i][0] = int(initPosAgent[0] + obsRadius * math.cos(obsAngle))
#                 obstaclePos[i][1] = int(initPosAgent[1] + obsRadius * math.sin(obsAngle))
#                 obstaclePos[i][0] = int(150 + i % 14 * 80)
#                 obstaclePos[i][1] = int(i / 14 * 80)
                obstaclePos[i][0] = int(150 + i % 7 * 150)
                obstaclePos[i][1] = int(150 + i / 7 * 150)
#                obstaclePos[i][0] = int(initPosAgent[0] - (obstacleRadius + agentRadius + random.randrange(0, dispSize[0])))
#                obstaclePos[i][1] = int(initPosAgent[1] + (obstacleRadius + agentRadius + random.randrange(0, dispSize[1])))

            episodes.append(e)
            
        #circle(Surface, color, pos, radius, width=0)
        pygame.draw.circle(screen, [100,255,100], goalPos, 10, 2)
        pygame.draw.circle(screen, [0, 255, 200], tmpGoalPos, 5, 5)
        pygame.display.flip()
        screen.fill([220,220,220])
        final = time.time()
        elapsed = final - start
        if frame >= 10:
            break
    print("Frame per second: " + str(frame / elapsed))
#    if e % 50 == 0:
#         agentMacro.actor.save_weights("./Practice004_DataSave/Actor_Macro.h5")
#         agentMacro.critic.save_weights("./Practice004_DataSave/Critic_Macro.h5")
#        agent.actor.save_weights("./Practice004_DataSave/Actor_Rev.h5")
#        agent.critic.save_weights("./Practice004_DataSave/Critic_Rev.h5")

    print score
    print("Percent of successful episodes: " + str(100.0 * sum(rList)/(e + 1)) + "%")
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               384
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 1161
# =================================================================
# Total params: 1,545
# Trainable params: 1,545
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /home/howoongjun/anaconda2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:2885: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/howoongjun/anaconda2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:1349: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 128)               384
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 513
# Trainable params: 513
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 128)               384
# _________________________________________________________________
# dense_6 (Dense)              (None, 9)                 1161
# =================================================================
# Total params: 1,545
# Trainable params: 1,545
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 128)               384
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 513
# Trainable params: 513
# Non-trainable params: 0
# _________________________________________________________________
# ('Episode ', 0, 'Starts!')
# Frame per second: 60.3511740575
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 1, 'Starts!')
# Frame per second: 218.971108768
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 2, 'Starts!')
# Frame per second: 198.401362314
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 3, 'Starts!')
# Frame per second: 219.81803698
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 4, 'Starts!')
# Frame per second: 225.255582647
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 5, 'Starts!')
# Frame per second: 223.51859056
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 6, 'Starts!')
# Frame per second: 196.881480682
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 7, 'Starts!')
# Frame per second: 211.981279882
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 8, 'Starts!')
# Frame per second: 222.855898027
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 9, 'Starts!')
# Frame per second: 224.059488451
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 10, 'Starts!')
# Frame per second: 219.620064928
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 11, 'Starts!')
# Frame per second: 192.271379129
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 12, 'Starts!')
# Frame per second: 227.118126438
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 13, 'Starts!')
# Frame per second: 228.154659588
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 14, 'Starts!')
# Frame per second: 216.132163948
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 15, 'Starts!')
# Frame per second: 219.993286338
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 16, 'Starts!')
# Frame per second: 198.310370588
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 17, 'Starts!')
# Frame per second: 197.507275313
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 18, 'Starts!')
# Frame per second: 220.035988018
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 19, 'Starts!')
# Frame per second: 197.765235637
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 20, 'Starts!')
# Frame per second: 207.206959752
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 21, 'Starts!')
# Frame per second: 201.356876074
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 22, 'Starts!')
# Frame per second: 233.809242433
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 23, 'Starts!')
# Frame per second: 208.991046026
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 24, 'Starts!')
# Frame per second: 225.795205564
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 25, 'Starts!')
# Frame per second: 210.145999299
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 26, 'Starts!')
# /home/howoongjun/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:51: DeprecationWarning: elementwise != comparison failed; this will raise an error in the future.
# Frame per second: 187.645298247
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 27, 'Starts!')
# Frame per second: 189.200220131
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 28, 'Starts!')
# Frame per second: 224.713717044
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 29, 'Starts!')
# Frame per second: 204.128210869
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 30, 'Starts!')
# Frame per second: 222.201831946
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 31, 'Starts!')
# Frame per second: 208.272910098
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 32, 'Starts!')
# Frame per second: 213.01479924
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 33, 'Starts!')
# Frame per second: 222.618147849
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 34, 'Starts!')
# Frame per second: 219.972518539
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 35, 'Starts!')
# Frame per second: 217.456656989
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 36, 'Starts!')
# Frame per second: 201.609490437
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 37, 'Starts!')
# Frame per second: 222.212426888
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 38, 'Starts!')
# Frame per second: 223.969755061
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 39, 'Starts!')
# Frame per second: 212.952071487
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 40, 'Starts!')
# Frame per second: 216.034200361
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 41, 'Starts!')
# Frame per second: 195.346489001
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 42, 'Starts!')
# Frame per second: 203.372026494
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 43, 'Starts!')
# Frame per second: 216.558446923
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 44, 'Starts!')
# Frame per second: 225.667645888
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 45, 'Starts!')
# Frame per second: 91.2392322016
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 46, 'Starts!')
# Frame per second: 220.497529177
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 47, 'Starts!')
# Frame per second: 224.739002304
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 48, 'Starts!')
# Frame per second: 202.539234907
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 49, 'Starts!')
# Frame per second: 212.174300139
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 50, 'Starts!')
# Frame per second: 197.448699541
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 51, 'Starts!')
# Frame per second: 212.440815665
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 52, 'Starts!')
# Frame per second: 170.668750025
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 53, 'Starts!')
# Frame per second: 173.919158747
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 54, 'Starts!')
# Frame per second: 166.367354062
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 55, 'Starts!')
# Frame per second: 162.76296693
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 56, 'Starts!')
# Frame per second: 149.48372335
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 57, 'Starts!')
# Frame per second: 177.465315534
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 58, 'Starts!')
# Frame per second: 168.534610578
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 59, 'Starts!')
# Frame per second: 162.135048629
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 60, 'Starts!')
# Frame per second: 180.414139589
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 61, 'Starts!')
# Frame per second: 203.873213079
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 62, 'Starts!')
# Frame per second: 191.11668026
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 63, 'Starts!')
# Frame per second: 204.210700566
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 64, 'Starts!')
# Frame per second: 183.69160966
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 65, 'Starts!')
# Frame per second: 175.571024927
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 66, 'Starts!')
# Frame per second: 176.597068718
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 67, 'Starts!')
# Frame per second: 176.634997642
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 68, 'Starts!')
# Frame per second: 219.173638364
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 69, 'Starts!')
# Frame per second: 207.082150457
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 70, 'Starts!')
# Frame per second: 178.307266536
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 71, 'Starts!')
# Frame per second: 184.178808238
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 72, 'Starts!')
# Frame per second: 180.740664133
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 73, 'Starts!')
# Frame per second: 184.532103795
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 74, 'Starts!')
# Frame per second: 205.305243372
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 75, 'Starts!')
# Frame per second: 216.623317598
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 76, 'Starts!')
# Frame per second: 190.243751984
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 77, 'Starts!')
# Frame per second: 166.1906894
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 78, 'Starts!')
# Frame per second: 153.784533932
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 79, 'Starts!')
# Frame per second: 167.112400244
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 80, 'Starts!')
# Frame per second: 218.889973228
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 81, 'Starts!')
# Frame per second: 229.268351344
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 82, 'Starts!')
# Frame per second: 207.559692592
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 83, 'Starts!')
# Frame per second: 177.907930623
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 84, 'Starts!')
# Frame per second: 181.113721155
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 85, 'Starts!')
# Frame per second: 182.342016485
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 86, 'Starts!')
# Frame per second: 192.04952449
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 87, 'Starts!')
# Frame per second: 216.562919515
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 88, 'Starts!')
# Frame per second: 212.188254102
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 89, 'Starts!')
# Frame per second: 224.405934502
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 90, 'Starts!')
# Frame per second: 206.611889421
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 91, 'Starts!')
# Frame per second: 202.171182331
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 92, 'Starts!')
# Frame per second: 188.224650526
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 93, 'Starts!')
# Frame per second: 205.905940108
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 94, 'Starts!')
# Frame per second: 196.706968193
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 95, 'Starts!')
# Frame per second: 203.836553789
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 96, 'Starts!')
# Frame per second: 202.02900645
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 97, 'Starts!')
# Frame per second: 195.598832275
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 98, 'Starts!')
# Frame per second: 198.965114845
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 99, 'Starts!')
# Frame per second: 213.082976443
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 100, 'Starts!')
# Frame per second: 220.433793194
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 101, 'Starts!')
# Frame per second: 236.456010193
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 102, 'Starts!')
# Frame per second: 220.48709713
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 103, 'Starts!')
# Frame per second: 230.250050779
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 104, 'Starts!')
# Frame per second: 219.89179214
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 105, 'Starts!')
# Frame per second: 200.762209277
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 106, 'Starts!')
# Frame per second: 222.261883313
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 107, 'Starts!')
# Frame per second: 209.208914427
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 108, 'Starts!')
# Frame per second: 222.10769907
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 109, 'Starts!')
# Frame per second: 213.807475073
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 110, 'Starts!')
# Frame per second: 225.849918153
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 111, 'Starts!')
# Frame per second: 206.620031922
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 112, 'Starts!')
# Frame per second: 201.033565475
# 0
# Percent of successful episodes: 0.0%
# ('Episode ', 113, 'Starts!')
# Goal Reached!
# Frame per second: 172.524638714
# 0
# Percent of successful episodes: 0.877192982456%
# ('Episode ', 114, 'Starts!')
# Frame per second: 212.188254102
# 0
# Percent of successful episodes: 0.869565217391%
# ('Episode ', 115, 'Starts!')
# Frame per second: 220.803975658
# 0
# Percent of successful episodes: 0.862068965517%
# ('Episode ', 116, 'Starts!')
# Frame per second: 218.632110632
# 0
# Percent of successful episodes: 0.854700854701%
# ('Episode ', 117, 'Starts!')
# Frame per second: 227.303982138
# 0
# Percent of successful episodes: 0.847457627119%
# ('Episode ', 118, 'Starts!')
# Frame per second: 210.948192183
# 0
# Percent of successful episodes: 0.840336134454%
# ('Episode ', 119, 'Starts!')
# Frame per second: 231.948636557
# 0
# Percent of successful episodes: 0.833333333333%
# ('Episode ', 120, 'Starts!')
# Frame per second: 227.359428444
# 0
# Percent of successful episodes: 0.826446280992%
# ('Episode ', 121, 'Starts!')
# Frame per second: 207.434458133
# 0
# Percent of successful episodes: 0.819672131148%
# ('Episode ', 122, 'Starts!')
# Frame per second: 207.180348437
# 0
# Percent of successful episodes: 0.813008130081%
# ('Episode ', 123, 'Starts!')
# Frame per second: 227.174712532
# 0
# Percent of successful episodes: 0.806451612903%
# ('Episode ', 124, 'Starts!')
# Frame per second: 232.353390873
# 0
# Percent of successful episodes: 0.8%
# ('Episode ', 125, 'Starts!')
# Frame per second: 201.547488047
# 0
# Percent of successful episodes: 0.793650793651%
# ('Episode ', 126, 'Starts!')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-24a48916f299> in <module>()
#      70         tmpGoalPos = goalFinder([x, y])
#      71         state = stateGenerator(tmpGoalPos, [x,y], -1)
# ---> 72         policyArr = agent.get_action(state)
#      73
#      74         if np.mean(tmpAction) == 0:
#
# <ipython-input-2-8b1c0f9abd0b> in get_action(self, state)
#      70     # using the output of policy network, pick action stochastically
#      71     def get_action(self, state):
# ---> 72         policy = self.actor.predict(state, batch_size=1).flatten()
#      73 #         print policy
#      74         return policy
#
# /home/howoongjun/anaconda2/lib/python2.7/site-packages/keras/models.pyc in predict(self, x, batch_size, verbose)
#    1004         if not self.built:
#    1005             self.build()
# -> 1006         return self.model.predict(x, batch_size=batch_size, verbose=verbose)
#    1007
#    1008     def predict_on_batch(self, x):
#
# /home/howoongjun/anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in predict(self, x, batch_size, verbose, steps)
#    1788         f = self.predict_function
#    1789         return self._predict_loop(f, ins, batch_size=batch_size,
# -> 1790                                   verbose=verbose, steps=steps)
#    1791
#    1792     def train_on_batch(self, x, y,
#
# /home/howoongjun/anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in _predict_loop(self, f, ins, batch_size, verbose, steps)
#    1297                 else:
#    1298                     ins_batch = _slice_arrays(ins, batch_ids)
# -> 1299                 batch_outs = f(ins_batch)
#    1300                 if not isinstance(batch_outs, list):
#    1301                     batch_outs = [batch_outs]
#
# /home/howoongjun/anaconda2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2355         session = get_session()
#    2356         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2357                               **self.session_kwargs)
#    2358         return updated[:len(self.outputs)]
#    2359
#
# /home/howoongjun/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     889     options_ptr = tf_session.TF_NewBufferFromString(
#     890         compat.as_bytes(options.SerializeToString())) if options else None
# --> 891     run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     892
#     893     try:
#
# KeyboardInterrupt:

# %%
print("Percent of successful episodes: " + str(100.0 * sum(rList)/num_episodes) + "%")

# plt.bar(range(len(rList)), rList, color = "Blue", width = 0.00001)
# plt.show()
# Out:
# Percent of successful episodes: 95.2%
