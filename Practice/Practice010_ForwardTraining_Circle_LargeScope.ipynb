# %%
import pygame, sys, random
import numpy as np
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import Adam
import math
import matplotlib.pyplot as plt
import pylab
from fractions import Fraction

num_episodes = 250

obstacleRadius = 10
agentRadius = 10

# get size of state and action from environment

boundaryPos = [100, 100]
boundaryLength = [70,70]
boundaryRadius = 40
dispSize = [1280, 960]
initPosAgentStandard = [dispSize[0] - 100, 100]#dispSize[1]]
initPosAgent = initPosAgentStandard#[boundaryPos[0] + boundaryLength[0] / 2, boundaryPos[1] + boundaryLength[1] / 2]
goalPos = [100, 900]
goalAngle = 0#random.randrange(0, 360) * math.pi / 180

obstacleRandomRange = 1000

moveObstacles = True
action_size = 9
obsNumber = 50
state_size = 2
# state_size = obsNumber + 1
# Out:
# Using TensorFlow backend.

# %%
# A2C(Advantage Actor-Critic) agent
class A2CAgent:
    def __init__(self, state_size, action_size):
        self.load_model = True
        
        # get size of state and action
        self.state_size = state_size
        self.action_size = action_size
        self.value_size = 1

        # These are hyper parameters for the Policy Gradient
        self.discount_factor = 0.99
        self.actor_lr = 0.00002
        self.critic_lr = 0.00005

        # create model for policy network
        self.actor = self.build_actor()
        self.critic = self.build_critic()
        self.actorGoal = self.build_actorGoal()
        self.criticGoal = self.build_criticGoal()

        if self.load_model:
            self.actor.load_weights("./Practice004_DataSave/Actor_For.h5")
            self.critic.load_weights("./Practice004_DataSave/Critic_For.h5")
            self.actorGoal.load_weights("./Practice004_DataSave/Actor_Rev.h5")
            self.criticGoal.load_weights("./Practice004_DataSave/Critic_Rev.h5")
#             print self.actor.weights
#             print self.critic.weights
    # approximate policy and value using Neural Network
    # actor: state is input and probability of each action is output of model
    def build_actor(self):
        actor = Sequential()
        actor.add(Dense(128, input_dim=self.state_size, activation='relu', kernel_initializer='glorot_normal'))
        actor.add(Dense(self.action_size, activation='softmax', kernel_initializer='glorot_normal'))
        actor.summary()
        # See note regarding crossentropy in cartpole_reinforce.py
        actor.compile(loss='categorical_crossentropy', optimizer=Adam(lr=self.actor_lr))
        return actor

    # critic: state is input and value of state is output of model
    def build_critic(self):
        critic = Sequential()
        critic.add(Dense(128, input_dim=self.state_size, activation='relu', kernel_initializer='glorot_normal'))
        critic.add(Dense(self.value_size, activation='linear', kernel_initializer='glorot_normal'))
        critic.summary()
        critic.compile(loss="mse", optimizer=Adam(lr=self.critic_lr))
        return critic

    def build_actorGoal(self):
        actorGoal = Sequential()
        actorGoal.add(Dense(128, input_dim=self.state_size, activation='relu', kernel_initializer='glorot_normal'))
        actorGoal.add(Dense(self.action_size, activation='softmax', kernel_initializer='glorot_normal'))
        actorGoal.summary()
        # See note regarding crossentropy in cartpole_reinforce.py
        actorGoal.compile(loss='categorical_crossentropy', optimizer=Adam(lr=self.actor_lr))
        return actorGoal

    # critic: state is input and value of state is output of model
    def build_criticGoal(self):
        criticGoal = Sequential()
        criticGoal.add(Dense(128, input_dim=self.state_size, activation='relu', kernel_initializer='glorot_normal'))
        criticGoal.add(Dense(self.value_size, activation='linear', kernel_initializer='glorot_normal'))
        criticGoal.summary()
        criticGoal.compile(loss="mse", optimizer=Adam(lr=self.critic_lr))
        return criticGoal

    
    # using the output of policy network, pick action stochastically
    def get_action(self, state):
        policy = self.actor.predict(state, batch_size=1).flatten()
#         print policy
        return policy
#         return np.random.choice(self.action_size, 1, p=policy)[0]


    # using the output of policy network, pick action stochastically
    def get_actionGoal(self, state):
        policy = self.actorGoal.predict(state, batch_size=1).flatten()
#         print policy
        return policy
#         return np.random.choice(self.action_size, 1, p=policy)[0]


    # update policy network every episode
    def train_model(self, state, action, reward, next_state, done):
        target = np.zeros((1, self.value_size))
        advantages = np.zeros((1, self.action_size))

        value = self.critic.predict(state)[0]
        next_value = self.critic.predict(next_state)[0]

        if done:
            advantages[0][action] = reward - value
            target[0][0] = reward
        else:
            advantages[0][action] = reward + self.discount_factor * (next_value) - value
            target[0][0] = reward + self.discount_factor * next_value

        self.actor.fit(state, advantages, epochs=1, verbose=0)
        self.critic.fit(state, target, epochs=1, verbose=0)

# %%
def stateGenerator(obsPosition, agtPosition, idx):
    returnSum = []
    if idx != -1:
        returnSum = returnSum + [agtPosition[0] - obsPosition[idx][0], agtPosition[1] - obsPosition[idx][1]]
    else:
        returnSum = returnSum + [agtPosition[0] - obsPosition[0], agtPosition[1] - obsPosition[1]]
    returnSum = np.reshape(returnSum, [1, state_size])
    return returnSum

# %%
def takeAction(action):
    xAction = 0
    yAction = 0
    if action == 0:
        xAction = 1
    elif action == 1:
        xAction = 1
        yAction = 1
    elif action == 2:
        xAction = 1
        yAction = -1            
    elif action == 3:
        xAction = -1
        yAction = 1
    elif action == 4:
        xAction = -1
    elif action == 5:
        xAction = -1
        yAction = -1
    elif action == 6:
        yAction = -1
    elif action == 7:
        yAction = 1
    elif action == 8:
        xAction = 0
        yAction = 0
        
    return [xAction, yAction]

# %%
def rangeFinder(allObsPos, rangeCenter):
    countObs = 0
    rangeObstacle = [[0,0] for _ in range(obsNumber)]
    allObsAgtDistance = [0 for _ in range(obsNumber)]
    for i in range(0, obsNumber):
        allObsAgtDistance[i] = math.sqrt((allObsPos[i][0] - rangeCenter[0])**2 + (allObsPos[i][1] - rangeCenter[1])**2)
        if math.sqrt((rangeCenter[0] - allObsPos[i][0])**2 + (rangeCenter[1] - allObsPos[i][1])**2) < boundaryRadius:
            rangeObstacle[countObs] = allObsPos[i]
            countObs += 1
    index = np.argmin(allObsAgtDistance)
    return [countObs, rangeObstacle, index]

# %%
def goalFinder(agtPos):
    if goalPos[0] == agtPos[0]:
        if goalPos[1] > agtPos[1]:
            goalAngle = 90 * math.pi / 180
        else:
            goalAngle = -90 * math.pi / 180
    else:
        goalAngle = math.atan(1.0*(goalPos[1]-agtPos[1])/(goalPos[0]-agtPos[0]))
    if goalPos[0] < agtPos[0]:
        goalAngle += math.pi
        
    tmpGoal = [0,0]
    tmpGoal[0] = int(math.floor(agtPos[0] + boundaryRadius * math.cos(goalAngle)))
    tmpGoal[1] = int(math.floor(agtPos[1] + boundaryRadius * math.sin(goalAngle)))
    return tmpGoal

# %%
def nearestAction(actionIdx):
    nearAction = []
    if actionIdx == 0:
        nearAction = [1, 2]
    elif actionIdx == 1:
        nearAction = [0, 7]
    elif actionIdx == 2:
        nearAction = [0, 6]
    elif actionIdx == 3:
        nearAction = [4, 7]
    elif actionIdx == 4:
        nearAction = [3, 5]
    elif actionIdx == 5:
        nearAction = [4, 6]
    elif actionIdx == 6:
        nearAction = [5, 2]
    elif actionIdx == 7:
        nearAction = [1, 3]
    else:
        nearAction = [8, 8]
    return nearAction

# %%
pygame.init()
screen = pygame.display.set_mode(dispSize)
screen.fill([200, 200, 200])

# make A2C agent
agent = A2CAgent(state_size, action_size)
agentGoal = A2CAgent(state_size, action_size)
rList, episodes = [], []

# Make Obstacles (obsNumber)
obstaclePos = [[0, 0] for _ in range(obsNumber)]
for i in range(0,obsNumber):
    obstaclePos[i][0] = int(150 + i % 7 * 150)
    obstaclePos[i][1] = int(150 + i / 7 * 150)
for e in range(num_episodes):
    # Initialize
    done = False
    score = 0
    x = initPosAgent[0]
    y = initPosAgent[1]
    print("Episode ", e, "Starts!")
    
    while not done:
        [rangeObsNumber, rangeObsPos, minIndex] = rangeFinder(obstaclePos, initPosAgent)
#         print rangeObsNumber

        macroState = stateGenerator([obstaclePos[minIndex][0], obstaclePos[minIndex][1]], [x, y], -1)
        macroPolicy = agent.get_action(macroState)
        
        tmpAction = []
        for i in range(0,rangeObsNumber):
            state = stateGenerator(rangeObsPos, [x,y], i)
            policyArr = agent.get_action(state)
            if i == 0:
                tmpAction = (policyArr)
            else:
                tmpAction = tmpAction * (policyArr)
#         print("0: ", tmpAction)
        
#         if tmpAction != []:
#             for j in range(0, action_size):
#                 if tmpAction[j] > 0.9999:
#                     tmpAction[j] = 1
# #                 elif tmpAction[j] > 0.995:
# #                     tmpAction[j] = 0.1
#                 else:
#                     tmpAction[j] = 0
#             tmpArgMax = np.argmax(tmpAction)
            
#         tmpAction = [round(elem,0) for elem in tmpAction]
            
#         if rangeObsNumber != 0:
#             tmpAction = tmpAction * (macroPolicy)
#         print("1:", macroPolicy)
    
        if rangeObsNumber == 0:
            tmpAction = [1.0/action_size for _ in range(0, action_size)]
        
        tmpGoalPos = goalFinder([x, y])
        state = stateGenerator(tmpGoalPos, [x,y], -1)
        policyArr = agentGoal.get_actionGoal(state)

#         if np.mean(tmpAction) == 0:
#             tmpAction[tmpArgMax] = 1
        
        tmpAction = tmpAction * np.asarray(policyArr)
    
        tmpAction = tmpAction / np.sum(tmpAction)
        action = np.random.choice(action_size, 1, p = tmpAction)[0]

        xMove = 0
        yMove = 0

        [xMove, yMove] = takeAction(action)

        x = x + xMove
        y = y + yMove

        wallFlag = 0
        collisionFlag = 0
#         [x, y] = ckWall(x, y)
        pygame.draw.circle(screen, [100, 100, 255], [x,y], 10, 0)
#         pic = pygame.image.load("image/vacumrobot.jpg")
#         pic = pygame.transform.scale(pic, (40, 40))
#         screen.blit(pic, [x - agentRadius,y - agentRadius])
#         next_state = stateGenerator(obstaclePos, [x,y])
        next_macroState = stateGenerator([obstaclePos[minIndex][0], obstaclePos[minIndex][1]], [x, y], -1)

        initPosAgent = [x,y]
   
        if math.sqrt((x -  goalPos[0])**2 + (y - goalPos[1])**2) <= agentRadius:
            print("Goal Reached!")
            collisionFlag = 1
            done = True
        for i in range(0,obsNumber):
            if moveObstacles:
                obstaclePos[i][0] = obstaclePos[i][0] + random.randrange(-1,2)
                obstaclePos[i][1] = obstaclePos[i][1] + random.randrange(-1,2)
                
            pygame.draw.circle(screen, [255, 50, 50], obstaclePos[i], obstacleRadius, 0)
            if math.sqrt((x - obstaclePos[i][0])**2 + (y - obstaclePos[i][1])**2) < 19:
                print("Collision!")
                collisionFlag = -1
                done = True
#                 break
        
        if not done:
            reward = 0

        else:
            if collisionFlag == 1:
#                 reward = 10000 * math.cos(math.atan2(y - initPosAgent[1], x - initPosAgent[0]))
                reward = 1000
                rList.append(1)
            elif collisionFlag == -1:
                reward = -1000
                rList.append(0)
        
#         agent.train_model(state, action, reward, next_state, done)
        
#         agent.train_model(macroState, action, reward, next_macroState, done)
#         macroState = next_macroState
    
        score += reward
#         state = next_state
#         if score >= 10000:
#             print "Success!"
#             done = True
        pygame.draw.circle(screen, [255,100,100], initPosAgent, boundaryRadius, 2)

        if done:
            # every episode, plot the play time
            initPosAgent = initPosAgentStandard
            obstaclePos = [[0, 0] for _ in range(obsNumber)]
            for i in range(0,obsNumber):
                obstaclePos[i][0] = int(150 + i % 7 * 150)
                obstaclePos[i][1] = int(150 + i / 7 * 150)
            episodes.append(e)
            
        #circle(Surface, color, pos, radius, width=0)
        pygame.draw.circle(screen, [100,255,100], goalPos, 10, 2)
        pygame.draw.circle(screen, [0, 255, 200], tmpGoalPos, 5, 5)
        pygame.display.flip()
        screen.fill([220,220,220])
#     if e % 50 == 0:
#         agent.actor.save_weights("./Practice004_DataSave/Actor_For.h5")
#         agent.critic.save_weights("./Practice004_DataSave/Critic_For.h5")
    print score
    print("Percent of successful episodes: " + str(100.0 * sum(rList)/(e + 1)) + "%")
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               384
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 1161
# =================================================================
# Total params: 1,545
# Trainable params: 1,545
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /home/howoongjun/anaconda2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:2885: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/howoongjun/anaconda2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:1349: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 128)               384
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 513
# Trainable params: 513
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 128)               384
# _________________________________________________________________
# dense_6 (Dense)              (None, 9)                 1161
# =================================================================
# Total params: 1,545
# Trainable params: 1,545
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 128)               384
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 513
# Trainable params: 513
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 128)               384
# _________________________________________________________________
# dense_10 (Dense)             (None, 9)                 1161
# =================================================================
# Total params: 1,545
# Trainable params: 1,545
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 128)               384
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 513
# Trainable params: 513
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 128)               384
# _________________________________________________________________
# dense_14 (Dense)             (None, 9)                 1161
# =================================================================
# Total params: 1,545
# Trainable params: 1,545
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 128)               384
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 513
# Trainable params: 513
# Non-trainable params: 0
# _________________________________________________________________
# ('Episode ', 0, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 1, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 2, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 3, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 4, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 5, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 6, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 7, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 8, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 9, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 10, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 11, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 12, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 13, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 14, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 15, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 16, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 17, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 18, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 19, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 20, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 21, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 22, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 23, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 24, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 25, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 26, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 27, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 28, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 29, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 30, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 31, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 32, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 33, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 34, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 35, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 36, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 37, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 38, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 39, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 40, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 41, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 42, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 43, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 44, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 45, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 46, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 47, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 48, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 49, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 50, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 51, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 52, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 53, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 54, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 55, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 56, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 57, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 58, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 59, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 60, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 61, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 62, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 63, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 64, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 65, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 66, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 67, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 68, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 69, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 70, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 71, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 72, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 73, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 74, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 75, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 76, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 77, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 78, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 79, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 80, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 81, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 82, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 83, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 84, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 85, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 100.0%
# ('Episode ', 86, 'Starts!')
# Goal Reached!
# Collision!
# -1000
# Percent of successful episodes: 98.8505747126%
# ('Episode ', 87, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.8636363636%
# ('Episode ', 88, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.8764044944%
# ('Episode ', 89, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.8888888889%
# ('Episode ', 90, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9010989011%
# ('Episode ', 91, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9130434783%
# ('Episode ', 92, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9247311828%
# ('Episode ', 93, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9361702128%
# ('Episode ', 94, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9473684211%
# ('Episode ', 95, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9583333333%
# ('Episode ', 96, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9690721649%
# ('Episode ', 97, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9795918367%
# ('Episode ', 98, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9898989899%
# ('Episode ', 99, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0%
# ('Episode ', 100, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0099009901%
# ('Episode ', 101, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0196078431%
# ('Episode ', 102, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0291262136%
# ('Episode ', 103, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0384615385%
# ('Episode ', 104, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0476190476%
# ('Episode ', 105, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0566037736%
# ('Episode ', 106, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0654205607%
# ('Episode ', 107, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0740740741%
# ('Episode ', 108, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0825688073%
# ('Episode ', 109, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0909090909%
# ('Episode ', 110, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0990990991%
# ('Episode ', 111, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1071428571%
# ('Episode ', 112, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1150442478%
# ('Episode ', 113, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1228070175%
# ('Episode ', 114, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1304347826%
# ('Episode ', 115, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1379310345%
# ('Episode ', 116, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1452991453%
# ('Episode ', 117, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1525423729%
# ('Episode ', 118, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1596638655%
# ('Episode ', 119, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1666666667%
# ('Episode ', 120, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.173553719%
# ('Episode ', 121, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1803278689%
# ('Episode ', 122, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1869918699%
# ('Episode ', 123, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1935483871%
# ('Episode ', 124, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.2%
# ('Episode ', 125, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.2063492063%
# ('Episode ', 126, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.2125984252%
# ('Episode ', 127, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.21875%
# ('Episode ', 128, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.2248062016%
# ('Episode ', 129, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.2307692308%
# ('Episode ', 130, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.2366412214%
# ('Episode ', 131, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.2424242424%
# ('Episode ', 132, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.2481203008%
# ('Episode ', 133, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.2537313433%
# ('Episode ', 134, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.2592592593%
# ('Episode ', 135, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.2647058824%
# ('Episode ', 136, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.2700729927%
# ('Episode ', 137, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.2753623188%
# ('Episode ', 138, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.2805755396%
# ('Episode ', 139, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.2857142857%
# ('Episode ', 140, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.2907801418%
# ('Episode ', 141, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.2957746479%
# ('Episode ', 142, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3006993007%
# ('Episode ', 143, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3055555556%
# ('Episode ', 144, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3103448276%
# ('Episode ', 145, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3150684932%
# ('Episode ', 146, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3197278912%
# ('Episode ', 147, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3243243243%
# ('Episode ', 148, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3288590604%
# ('Episode ', 149, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3333333333%
# ('Episode ', 150, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3377483444%
# ('Episode ', 151, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3421052632%
# ('Episode ', 152, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3464052288%
# ('Episode ', 153, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3506493506%
# ('Episode ', 154, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3548387097%
# ('Episode ', 155, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.358974359%
# ('Episode ', 156, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3630573248%
# ('Episode ', 157, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3670886076%
# ('Episode ', 158, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3710691824%
# ('Episode ', 159, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.375%
# ('Episode ', 160, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3788819876%
# ('Episode ', 161, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3827160494%
# ('Episode ', 162, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3865030675%
# ('Episode ', 163, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3902439024%
# ('Episode ', 164, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3939393939%
# ('Episode ', 165, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.3975903614%
# ('Episode ', 166, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.4011976048%
# ('Episode ', 167, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.4047619048%
# ('Episode ', 168, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.4082840237%
# ('Episode ', 169, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.4117647059%
# ('Episode ', 170, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.4152046784%
# ('Episode ', 171, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.4186046512%
# ('Episode ', 172, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.4219653179%
# ('Episode ', 173, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.4252873563%
# ('Episode ', 174, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.4285714286%
# ('Episode ', 175, 'Starts!')
# Collision!
# -1000
# Percent of successful episodes: 98.8636363636%
# ('Episode ', 176, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.8700564972%
# ('Episode ', 177, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.8764044944%
# ('Episode ', 178, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.8826815642%
# ('Episode ', 179, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.8888888889%
# ('Episode ', 180, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.8950276243%
# ('Episode ', 181, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9010989011%
# ('Episode ', 182, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9071038251%
# ('Episode ', 183, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9130434783%
# ('Episode ', 184, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9189189189%
# ('Episode ', 185, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9247311828%
# ('Episode ', 186, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9304812834%
# ('Episode ', 187, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9361702128%
# ('Episode ', 188, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9417989418%
# ('Episode ', 189, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9473684211%
# ('Episode ', 190, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9528795812%
# ('Episode ', 191, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9583333333%
# ('Episode ', 192, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9637305699%
# ('Episode ', 193, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9690721649%
# ('Episode ', 194, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9743589744%
# ('Episode ', 195, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9795918367%
# ('Episode ', 196, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9847715736%
# ('Episode ', 197, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9898989899%
# ('Episode ', 198, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.9949748744%
# ('Episode ', 199, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0%
# ('Episode ', 200, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0049751244%
# ('Episode ', 201, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0099009901%
# ('Episode ', 202, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0147783251%
# ('Episode ', 203, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0196078431%
# ('Episode ', 204, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0243902439%
# ('Episode ', 205, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0291262136%
# ('Episode ', 206, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0338164251%
# ('Episode ', 207, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0384615385%
# ('Episode ', 208, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.043062201%
# ('Episode ', 209, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0476190476%
# ('Episode ', 210, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0521327014%
# ('Episode ', 211, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0566037736%
# ('Episode ', 212, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0610328638%
# ('Episode ', 213, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0654205607%
# ('Episode ', 214, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0697674419%
# ('Episode ', 215, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0740740741%
# ('Episode ', 216, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0783410138%
# ('Episode ', 217, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0825688073%
# ('Episode ', 218, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0867579909%
# ('Episode ', 219, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0909090909%
# ('Episode ', 220, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0950226244%
# ('Episode ', 221, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.0990990991%
# ('Episode ', 222, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1031390135%
# ('Episode ', 223, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1071428571%
# ('Episode ', 224, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1111111111%
# ('Episode ', 225, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1150442478%
# ('Episode ', 226, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1189427313%
# ('Episode ', 227, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1228070175%
# ('Episode ', 228, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1266375546%
# ('Episode ', 229, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1304347826%
# ('Episode ', 230, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1341991342%
# ('Episode ', 231, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1379310345%
# ('Episode ', 232, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1416309013%
# ('Episode ', 233, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1452991453%
# ('Episode ', 234, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1489361702%
# ('Episode ', 235, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1525423729%
# ('Episode ', 236, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1561181435%
# ('Episode ', 237, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1596638655%
# ('Episode ', 238, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1631799163%
# ('Episode ', 239, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1666666667%
# ('Episode ', 240, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 99.1701244813%
# ('Episode ', 241, 'Starts!')
# Collision!
# -1000
# Percent of successful episodes: 98.7603305785%
# ('Episode ', 242, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.7654320988%
# ('Episode ', 243, 'Starts!')
# Goal Reached!
# 1000
# Percent of successful episodes: 98.7704918033%
# ('Episode ', 244, 'Starts!')

# %%
print("Percent of successful episodes: " + str(100.0 * sum(rList)/num_episodes) + "%")

# plt.bar(range(len(rList)), rList, color = "Blue",width = 0.00001)
# plt.show()
# Out:
# Percent of successful episodes: 21.0%
