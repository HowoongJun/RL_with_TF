# %%
import gym
import numpy as np
# import mujoco_py
env = gym.make('Ant-v1')
for i in xrange(10):
    env.reset()
    for i in xrange(10):
        a = (np.random.rand(*env.action_space.shape) - 0.5) * 1.1
        print a
        # returns observation, reward, done, info
        o, r, d, i = env.step(a)
        env.render()
# Out:
# [2018-01-04 12:09:12,477] Making new env: Ant-v1
# [ 0.40487904  0.38759673 -0.06951504 -0.34964595  0.06363033  0.43114666
#   0.20087711 -0.40584179]
# [ 0.52352991  0.22862301 -0.14918693 -0.22186367 -0.33113698  0.40566954
#   0.17913671 -0.25424643]
# [-0.52795247  0.10997764 -0.1380674  -0.37267261  0.11200245 -0.42697183
#   0.09372133 -0.48788855]
# [-0.08729051 -0.10746065  0.49357001  0.4914483  -0.00194108  0.20078933
#  -0.22028315 -0.22212172]
# [-0.04399908 -0.5491578   0.52694987  0.50406108 -0.02517692 -0.00089146
#  -0.02890823  0.11542301]
# [-0.54475203 -0.32855308  0.38603881 -0.05960396 -0.46161592 -0.1744694
#   0.14322357  0.01436383]
# [-0.11907542 -0.2072848   0.27174935 -0.53843142 -0.10706218 -0.15295168
#   0.10360244  0.40108768]
# [ 0.38119967 -0.21953107  0.20398803 -0.02328011 -0.29888223  0.10334642
#   0.18490429 -0.17442331]
# [ 0.1532962  -0.0083593   0.11948255  0.18939572  0.02667519  0.13923657
#   0.09159479  0.04598798]
# ...
